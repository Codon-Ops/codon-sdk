# %% [markdown]
# # Converting a LangGraph Workflow into a Codon Workload
#
# This notebook shows how to take an existing LangGraph graph built with LangChain components and wrap it with `CodonWorkload` using the `LangGraphWorkloadAdapter`. We get instrumentation, audit trails, logic IDs, and the token runtime without changing the LangGraph logic.> **Colab friendly** – install LangChain, LangGraph, and Codon SDK (from source) before running the cells.

# %% [markdown]
# ## 0. Setup
#
# Install dependencies and configure environment variables. Adjust paths as needed.

# %%
# %%capture --no-stderr
# %pip install --quiet langchain langgraph langchain-openai openai tiktoken git+https://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@github.com/Codon-Ops/codon-sdk.git#subdirectory=sdk git+https://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@github.com/Codon-Ops/codon-sdk.git#subdirectory=instrumentation-packages/codon-instrumentation-langgraph

# %%
from getpass import getpass
import os

os.environ["ORG_NAMESPACE"] = "codon-example-org"
os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI Api Key:\t")
# Out:
# Enter your OpenAI Api Key:	··········

# %% [markdown]
# ## 1. Build an Existing LangGraph Workflow
#
# We design a simple research workflow using LangChain tools:- Planner synthesises a plan.- Researcher expands insights.- Writer produces a summary.- Critic reviews and loop back if needed.

# %%
from typing import Dict, TypedDict
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langgraph.graph import StateGraph

llm_planner = ChatOpenAI(model="gpt-4.1-mini")
llm_researcher = ChatOpenAI(model="gpt-4.1-mini")
llm_writer = ChatOpenAI(model="gpt-4.1-mini")
llm_critic = ChatOpenAI(model="gpt-4.1-mini")

async def planner(state: Dict):
  topic = state["topic"]
  prompt = f"Draft a research plan for {topic}. Keep it short."
  result = await llm_planner.ainvoke([HumanMessage(content=prompt)])
  return {"plan": result.content}

async def researcher(state: Dict):
  prompt = (
      "Given this plan, provide three bullet insights."
      f"Plan:{state['plan']}"
  )
  result = await llm_researcher.ainvoke([HumanMessage(content=prompt)])
  return {"insights": result.content}

async def writer(state: Dict):
  prompt = (
      "Write a 120-word executive summary using the plan and insights."
      f"Plan: {state['plan']}"
      f"Insights: {state['insights']}"
  )
  result = await llm_writer.ainvoke([HumanMessage(content=prompt)])
  return {"draft": result.content}

async def critic(state: Dict):
  prompt = (
      "Review this draft. Return JSON with fields 'decision' and 'feedback'."
      "Decision must be ACCEPT or REVISION."
      f"Draft: {state['draft']}"
  )
  result = await llm_critic.ainvoke([HumanMessage(content=prompt)])
  return {"critique": result.content}

async def finalize(state: Dict):
  return {"summary": state['draft'], "critique": state.get('critique', '')}

class ResearchState(TypedDict, total=False):
    topic: str
    plan: str
    insights: str
    draft: str
    critique: str

graph = StateGraph(ResearchState)
graph.add_node("planner", planner)
graph.add_node("researcher", researcher)
graph.add_node("writer", writer)
graph.add_node("critic", critic)
graph.add_node("finalize", finalize)
graph.set_entry_point("planner")


# Edges
graph.add_edge("planner", "researcher")
graph.add_edge("researcher", "writer")
graph.add_edge("writer", "critic")
# cycle: critic -> writer if revision required
# graph.add_edge("critic", "writer")
# finalize when critic approves
graph.add_edge("critic", "finalize")

compiled_graph = graph.compile()

# %% [markdown]
# ## 2. Run the LangGraph Workflow Directly
#
# Before wrapping with Codon, let's run the LangGraph graph to confirm it works.

# %%
initial_state = {"topic": "Community gardens and urban wellbeing"}
result = await compiled_graph.ainvoke(initial_state)

result
# Out:
# {'topic': 'Community gardens and urban wellbeing',
#  'plan': '**Research Plan: Community Gardens and Urban Wellbeing**\n\n**Objective:**  \nTo investigate the impact of community gardens on the physical, mental, and social wellbeing of urban residents.\n\n**Background:**  \nCommunity gardens are increasingly recognized as valuable urban spaces that promote sustainability, social cohesion, and health. However, comprehensive research quantifying their contribution to urban wellbeing remains limited.\n\n**Research Questions:**  \n1. How do community gardens affect the physical health of participants?  \n2. What is the impact of community gardens on mental health and stress levels?  \n3. In what ways do community gardens foster social connections and community engagement?  \n\n**Methodology:**  \n- **Literature Review:** Synthesize existing studies on community gardens and urban wellbeing.  \n- **Surveys:** Administer questionnaires to community garden participants and non-participants in selected urban areas.  \n- **Interviews/Focus Groups:** Conduct qualitative interviews with gardeners to explore personal experiences.  \n- **Health Metrics:** Collect data on physical activity levels, stress (using validated scales), and social interaction frequency.  \n- **Comparative Analysis:** Compare wellbeing indicators between community gardeners and a control group.  \n\n**Expected Outcomes:**  \n- Empirical evidence of the benefits of community gardens on wellbeing.  \n- Recommendations for urban planning and public health policies to support community gardening initiatives.  \n\n**Timeline:**  \n- Month 1-2: Literature review and research design  \n- Month 3-5: Data collection  \n- Month 6-7: Data analysis  \n- Month 8: Reporting and dissemination  \n\n**Resources Needed:**  \n- Access to community garden sites and participants  \n- Survey and interview tools  \n- Statistical analysis software  \n\n**Significance:**  \nThis research will inform urban development strategies that leverage community gardens to enhance quality of life and foster resilient communities.',
#  'insights': '- Community gardens are hypothesized to positively influence physical health, mental wellbeing, and social connectedness among urban residents, addressing gaps in existing research by providing empirical data.  \n- The mixed-methods approach—combining surveys, qualitative interviews, and health metrics—enables a comprehensive understanding of how community gardens contribute to multiple dimensions of urban wellbeing.  \n- Findings from this study are expected to inform urban planners and public health policymakers, promoting community gardening as a strategic tool for sustainable and inclusive urban development.',
#  'draft': 'This research investigates the impact of community gardens on the physical, mental, and social wellbeing of urban residents. Recognizing a gap in empirical data, the study employs a mixed-methods approach, combining literature review, surveys, interviews, and health metrics to comprehensively assess how community gardening influences health and social connectedness. Surveys and qualitative data will compare wellbeing indicators between gardeners and non-participants, exploring physical activity, stress reduction, and social engagement. The findings aim to provide robust evidence supporting the role of community gardens in enhancing urban quality of life. Ultimately, this research will offer actionable recommendations for urban planners and public health policymakers, advocating community gardening as a strategic tool for fostering sustainable, healthy, and socially resilient cities. Data collection and analysis are scheduled over eight months, ensuring rigorous and timely outcomes.',
#  'critique': '{\n  "decision": "ACCEPT",\n  "feedback": "The draft clearly outlines a relevant and well-structured research study addressing the impact of community gardens on urban residents\' wellbeing. The mixed-methods approach combining literature review, surveys, interviews, and health metrics is appropriate and thorough. The research objectives, methodology, and intended outcomes are clearly presented, with a reasonable timeline for data collection and analysis. No major revisions are necessary."\n}'}

# %%
type(graph)
# Out:
# langgraph.graph.state.StateGraph

# %% [markdown]
# ## 3. Convert to Codon Workload
#
# Using `LangGraphWorkloadAdapter` we can wrap the graph with zero manual instrumentation.

# %%
from codon.instrumentation.langgraph import (
    initialize_telemetry,
    LangGraphWorkloadAdapter,
)

initialize_telemetry(service_name="codon-langgraph-notebook")

codon_workload = LangGraphWorkloadAdapter.from_langgraph(
    graph,
    name="LangGraphResearchAgent",
    version="0.1.0",
    description="Wrapped LangGraph research agent",
    tags=["langgraph", "demo"],
    role_overrides={
        "planner": "planner",
        "researcher": "analyst",
        "writer": "author",
        "critic": "qa",
        "finalize": "publisher",
    },)

codon_workload

# %% [markdown]
# ## 4. Execute the Codon WorkloadNow we execute the workload with the same initial state. Tokens drive the LangGraph nodes under the hood, and we capture a ledger plus telemetry.

# %%
report = await codon_workload.execute_async({"state": initial_state}, deployment_id="notebook-demo", max_steps=40)

final_entry = report.node_results("finalize")[-1]

final_entry
# Out:
# WARNING:opentelemetry.exporter.otlp.proto.grpc.exporter:Transient error StatusCode.UNAVAILABLE encountered while exporting traces to localhost:4317, retrying in 0.84s.
# {'topic': 'Community gardens and urban wellbeing',
#  'plan': '**Research Plan: Community Gardens and Urban Wellbeing**\n\n**Objective:**  \nTo explore how community gardens impact the physical, mental, and social wellbeing of urban residents.\n\n**Research Questions:**  \n1. How do community gardens influence mental health outcomes in urban populations?  \n2. What role do community gardens play in fostering social cohesion and community engagement?  \n3. Can participation in community gardening improve physical health indicators among city dwellers?\n\n**Methodology:**  \n- **Literature Review:** Synthesize existing studies on community gardens and urban wellbeing.  \n- **Survey:** Design and distribute questionnaires to urban residents participating in community gardens and a control group not involved.  \n- **Interviews/Focus Groups:** Conduct qualitative interviews with gardeners to gather in-depth insights on personal and social wellbeing effects.  \n- **Health Data Analysis:** Collect/compare physical health data, such as BMI, activity levels, from participants and non-participants.  \n- **Case Studies:** Select diverse community gardens in multiple urban settings for observational studies.\n\n**Timeline:**  \n- Months 1–2: Literature review and research design  \n- Months 3–5: Data collection (surveys, interviews, health data)  \n- Months 6–7: Data analysis  \n- Month 8: Report writing and dissemination  \n\n**Expected Outcomes:**  \n- Evidence of community gardens’ benefits on mental health and social bonds.  \n- Recommendations for urban planning and public health policies to integrate community gardening.',
#  'insights': '- Community gardens are expected to have a multifaceted positive impact on urban residents, improving mental health, enhancing social cohesion, and supporting better physical health outcomes.  \n- Combining quantitative (surveys, health data) and qualitative (interviews, focus groups, case studies) methodologies will provide a comprehensive understanding of the personal and communal benefits of community gardening.  \n- The research timeline and structured approach aim to produce actionable recommendations that can inform urban planning and public health policies to better integrate community gardens into city environments.',
#  'draft': 'This research investigates the impact of community gardens on the physical, mental, and social wellbeing of urban residents. Combining quantitative surveys and health data with qualitative interviews, focus groups, and case studies, the study explores how community gardening influences mental health, fosters social cohesion, and improves physical health indicators. A comprehensive literature review and multi-city observations support this mixed-methods approach. Preliminary insights suggest that community gardens significantly enhance mental wellbeing, strengthen community bonds, and promote healthier lifestyles among participants. The research aims to generate robust evidence and actionable recommendations for urban planners and public health policymakers to effectively integrate community gardens into city environments, ultimately advancing urban wellbeing and social resilience. The project is planned over eight months, ensuring rigorous data collection, analysis, and dissemination of findings.',
#  'critique': '```json\n{\n  "decision": "ACCEPT",\n  "feedback": "The draft is clear, well-structured, and presents a compelling study on the impact of community gardens on urban residents\' wellbeing. It effectively outlines the mixed-methods approach, including both quantitative and qualitative data sources, and demonstrates relevance through multi-city observations and a comprehensive literature review. The objectives are meaningful and aligned with public health and urban planning interests. The timeframe and scope appear reasonable. No major revisions are needed, though adding more details about participant selection or data analysis methods could strengthen the proposal further in future drafts."\n}\n```',
#  'summary': 'This research investigates the impact of community gardens on the physical, mental, and social wellbeing of urban residents. Combining quantitative surveys and health data with qualitative interviews, focus groups, and case studies, the study explores how community gardening influences mental health, fosters social cohesion, and improves physical health indicators. A comprehensive literature review and multi-city observations support this mixed-methods approach. Preliminary insights suggest that community gardens significantly enhance mental wellbeing, strengthen community bonds, and promote healthier lifestyles among participants. The research aims to generate robust evidence and actionable recommendations for urban planners and public health policymakers to effectively integrate community gardens into city environments, ultimately advancing urban wellbeing and social resilience. The project is planned over eight months, ensuring rigorous data collection, analysis, and dissemination of findings.'}

# %%
report.results
# Out:
# {'planner': [NodeExecutionRecord(node='planner', token_id='a3ecbb96-2b65-4934-b96f-d3d4a087c67d', result={'topic': 'Community gardens and urban wellbeing', 'plan': '**Research Plan: Community Gardens and Urban Wellbeing**\n\n**Objective:**  \nTo explore how community gardens impact the physical, mental, and social wellbeing of urban residents.\n\n**Research Questions:**  \n1. How do community gardens influence mental health outcomes in urban populations?  \n2. What role do community gardens play in fostering social cohesion and community engagement?  \n3. Can participation in community gardening improve physical health indicators among city dwellers?\n\n**Methodology:**  \n- **Literature Review:** Synthesize existing studies on community gardens and urban wellbeing.  \n- **Survey:** Design and distribute questionnaires to urban residents participating in community gardens and a control group not involved.  \n- **Interviews/Focus Groups:** Conduct qualitative interviews with gardeners to gather in-depth insights on personal and social wellbeing effects.  \n- **Health Data Analysis:** Collect/compare physical health data, such as BMI, activity levels, from participants and non-participants.  \n- **Case Studies:** Select diverse community gardens in multiple urban settings for observational studies.\n\n**Timeline:**  \n- Months 1–2: Literature review and research design  \n- Months 3–5: Data collection (surveys, interviews, health data)  \n- Months 6–7: Data analysis  \n- Month 8: Report writing and dissemination  \n\n**Expected Outcomes:**  \n- Evidence of community gardens’ benefits on mental health and social bonds.  \n- Recommendations for urban planning and public health policies to integrate community gardening.'}, started_at=datetime.datetime(2025, 9, 25, 4, 47, 49, 154450, tzinfo=datetime.timezone.utc), finished_at=datetime.datetime(2025, 9, 25, 4, 47, 52, 843749, tzinfo=datetime.timezone.utc))],
#  'researcher': [NodeExecutionRecord(node='researcher', token_id='8c05627b-58c9-4586-97d8-81bd72b7ace5', result={'topic': 'Community gardens and urban wellbeing', 'plan': '**Research Plan: Community Gardens and Urban Wellbeing**\n\n**Objective:**  \nTo explore how community gardens impact the physical, mental, and social wellbeing of urban residents.\n\n**Research Questions:**  \n1. How do community gardens influence mental health outcomes in urban populations?  \n2. What role do community gardens play in fostering social cohesion and community engagement?  \n3. Can participation in community gardening improve physical health indicators among city dwellers?\n\n**Methodology:**  \n- **Literature Review:** Synthesize existing studies on community gardens and urban wellbeing.  \n- **Survey:** Design and distribute questionnaires to urban residents participating in community gardens and a control group not involved.  \n- **Interviews/Focus Groups:** Conduct qualitative interviews with gardeners to gather in-depth insights on personal and social wellbeing effects.  \n- **Health Data Analysis:** Collect/compare physical health data, such as BMI, activity levels, from participants and non-participants.  \n- **Case Studies:** Select diverse community gardens in multiple urban settings for observational studies.\n\n**Timeline:**  \n- Months 1–2: Literature review and research design  \n- Months 3–5: Data collection (surveys, interviews, health data)  \n- Months 6–7: Data analysis  \n- Month 8: Report writing and dissemination  \n\n**Expected Outcomes:**  \n- Evidence of community gardens’ benefits on mental health and social bonds.  \n- Recommendations for urban planning and public health policies to integrate community gardening.', 'insights': '- Community gardens are expected to have a multifaceted positive impact on urban residents, improving mental health, enhancing social cohesion, and supporting better physical health outcomes.  \n- Combining quantitative (surveys, health data) and qualitative (interviews, focus groups, case studies) methodologies will provide a comprehensive understanding of the personal and communal benefits of community gardening.  \n- The research timeline and structured approach aim to produce actionable recommendations that can inform urban planning and public health policies to better integrate community gardens into city environments.'}, started_at=datetime.datetime(2025, 9, 25, 4, 47, 52, 843812, tzinfo=datetime.timezone.utc), finished_at=datetime.datetime(2025, 9, 25, 4, 47, 54, 472381, tzinfo=datetime.timezone.utc))],
#  'writer': [NodeExecutionRecord(node='writer', token_id='ca6a667c-8618-48f9-a833-1c930b6ef8ec', result={'topic': 'Community gardens and urban wellbeing', 'plan': '**Research Plan: Community Gardens and Urban Wellbeing**\n\n**Objective:**  \nTo explore how community gardens impact the physical, mental, and social wellbeing of urban residents.\n\n**Research Questions:**  \n1. How do community gardens influence mental health outcomes in urban populations?  \n2. What role do community gardens play in fostering social cohesion and community engagement?  \n3. Can participation in community gardening improve physical health indicators among city dwellers?\n\n**Methodology:**  \n- **Literature Review:** Synthesize existing studies on community gardens and urban wellbeing.  \n- **Survey:** Design and distribute questionnaires to urban residents participating in community gardens and a control group not involved.  \n- **Interviews/Focus Groups:** Conduct qualitative interviews with gardeners to gather in-depth insights on personal and social wellbeing effects.  \n- **Health Data Analysis:** Collect/compare physical health data, such as BMI, activity levels, from participants and non-participants.  \n- **Case Studies:** Select diverse community gardens in multiple urban settings for observational studies.\n\n**Timeline:**  \n- Months 1–2: Literature review and research design  \n- Months 3–5: Data collection (surveys, interviews, health data)  \n- Months 6–7: Data analysis  \n- Month 8: Report writing and dissemination  \n\n**Expected Outcomes:**  \n- Evidence of community gardens’ benefits on mental health and social bonds.  \n- Recommendations for urban planning and public health policies to integrate community gardening.', 'insights': '- Community gardens are expected to have a multifaceted positive impact on urban residents, improving mental health, enhancing social cohesion, and supporting better physical health outcomes.  \n- Combining quantitative (surveys, health data) and qualitative (interviews, focus groups, case studies) methodologies will provide a comprehensive understanding of the personal and communal benefits of community gardening.  \n- The research timeline and structured approach aim to produce actionable recommendations that can inform urban planning and public health policies to better integrate community gardens into city environments.', 'draft': 'This research investigates the impact of community gardens on the physical, mental, and social wellbeing of urban residents. Combining quantitative surveys and health data with qualitative interviews, focus groups, and case studies, the study explores how community gardening influences mental health, fosters social cohesion, and improves physical health indicators. A comprehensive literature review and multi-city observations support this mixed-methods approach. Preliminary insights suggest that community gardens significantly enhance mental wellbeing, strengthen community bonds, and promote healthier lifestyles among participants. The research aims to generate robust evidence and actionable recommendations for urban planners and public health policymakers to effectively integrate community gardens into city environments, ultimately advancing urban wellbeing and social resilience. The project is planned over eight months, ensuring rigorous data collection, analysis, and dissemination of findings.'}, started_at=datetime.datetime(2025, 9, 25, 4, 47, 54, 472488, tzinfo=datetime.timezone.utc), finished_at=datetime.datetime(2025, 9, 25, 4, 47, 59, 76565, tzinfo=datetime.timezone.utc))],
#  'critic': [NodeExecutionRecord(node='critic', token_id='b031e044-0526-458f-af1d-89f44fd59749', result={'topic': 'Community gardens and urban wellbeing', 'plan': '**Research Plan: Community Gardens and Urban Wellbeing**\n\n**Objective:**  \nTo explore how community gardens impact the physical, mental, and social wellbeing of urban residents.\n\n**Research Questions:**  \n1. How do community gardens influence mental health outcomes in urban populations?  \n2. What role do community gardens play in fostering social cohesion and community engagement?  \n3. Can participation in community gardening improve physical health indicators among city dwellers?\n\n**Methodology:**  \n- **Literature Review:** Synthesize existing studies on community gardens and urban wellbeing.  \n- **Survey:** Design and distribute questionnaires to urban residents participating in community gardens and a control group not involved.  \n- **Interviews/Focus Groups:** Conduct qualitative interviews with gardeners to gather in-depth insights on personal and social wellbeing effects.  \n- **Health Data Analysis:** Collect/compare physical health data, such as BMI, activity levels, from participants and non-participants.  \n- **Case Studies:** Select diverse community gardens in multiple urban settings for observational studies.\n\n**Timeline:**  \n- Months 1–2: Literature review and research design  \n- Months 3–5: Data collection (surveys, interviews, health data)  \n- Months 6–7: Data analysis  \n- Month 8: Report writing and dissemination  \n\n**Expected Outcomes:**  \n- Evidence of community gardens’ benefits on mental health and social bonds.  \n- Recommendations for urban planning and public health policies to integrate community gardening.', 'insights': '- Community gardens are expected to have a multifaceted positive impact on urban residents, improving mental health, enhancing social cohesion, and supporting better physical health outcomes.  \n- Combining quantitative (surveys, health data) and qualitative (interviews, focus groups, case studies) methodologies will provide a comprehensive understanding of the personal and communal benefits of community gardening.  \n- The research timeline and structured approach aim to produce actionable recommendations that can inform urban planning and public health policies to better integrate community gardens into city environments.', 'draft': 'This research investigates the impact of community gardens on the physical, mental, and social wellbeing of urban residents. Combining quantitative surveys and health data with qualitative interviews, focus groups, and case studies, the study explores how community gardening influences mental health, fosters social cohesion, and improves physical health indicators. A comprehensive literature review and multi-city observations support this mixed-methods approach. Preliminary insights suggest that community gardens significantly enhance mental wellbeing, strengthen community bonds, and promote healthier lifestyles among participants. The research aims to generate robust evidence and actionable recommendations for urban planners and public health policymakers to effectively integrate community gardens into city environments, ultimately advancing urban wellbeing and social resilience. The project is planned over eight months, ensuring rigorous data collection, analysis, and dissemination of findings.', 'critique': '```json\n{\n  "decision": "ACCEPT",\n  "feedback": "The draft is clear, well-structured, and presents a compelling study on the impact of community gardens on urban residents\' wellbeing. It effectively outlines the mixed-methods approach, including both quantitative and qualitative data sources, and demonstrates relevance through multi-city observations and a comprehensive literature review. The objectives are meaningful and aligned with public health and urban planning interests. The timeframe and scope appear reasonable. No major revisions are needed, though add ...
#  'finalize': [NodeExecutionRecord(node='finalize', token_id='4df07595-b89d-4208-bc38-2e988e13bae7', result={'topic': 'Community gardens and urban wellbeing', 'plan': '**Research Plan: Community Gardens and Urban Wellbeing**\n\n**Objective:**  \nTo explore how community gardens impact the physical, mental, and social wellbeing of urban residents.\n\n**Research Questions:**  \n1. How do community gardens influence mental health outcomes in urban populations?  \n2. What role do community gardens play in fostering social cohesion and community engagement?  \n3. Can participation in community gardening improve physical health indicators among city dwellers?\n\n**Methodology:**  \n- **Literature Review:** Synthesize existing studies on community gardens and urban wellbeing.  \n- **Survey:** Design and distribute questionnaires to urban residents participating in community gardens and a control group not involved.  \n- **Interviews/Focus Groups:** Conduct qualitative interviews with gardeners to gather in-depth insights on personal and social wellbeing effects.  \n- **Health Data Analysis:** Collect/compare physical health data, such as BMI, activity levels, from participants and non-participants.  \n- **Case Studies:** Select diverse community gardens in multiple urban settings for observational studies.\n\n**Timeline:**  \n- Months 1–2: Literature review and research design  \n- Months 3–5: Data collection (surveys, interviews, health data)  \n- Months 6–7: Data analysis  \n- Month 8: Report writing and dissemination  \n\n**Expected Outcomes:**  \n- Evidence of community gardens’ benefits on mental health and social bonds.  \n- Recommendations for urban planning and public health policies to integrate community gardening.', 'insights': '- Community gardens are expected to have a multifaceted positive impact on urban residents, improving mental health, enhancing social cohesion, and supporting better physical health outcomes.  \n- Combining quantitative (surveys, health data) and qualitative (interviews, focus groups, case studies) methodologies will provide a comprehensive understanding of the personal and communal benefits of community gardening.  \n- The research timeline and structured approach aim to produce actionable recommendations that can inform urban planning and public health policies to better integrate community gardens into city environments.', 'draft': 'This research investigates the impact of community gardens on the physical, mental, and social wellbeing of urban residents. Combining quantitative surveys and health data with qualitative interviews, focus groups, and case studies, the study explores how community gardening influences mental health, fosters social cohesion, and improves physical health indicators. A comprehensive literature review and multi-city observations support this mixed-methods approach. Preliminary insights suggest that community gardens significantly enhance mental wellbeing, strengthen community bonds, and promote healthier lifestyles among participants. The research aims to generate robust evidence and actionable recommendations for urban planners and public health policymakers to effectively integrate community gardens into city environments, ultimately advancing urban wellbeing and social resilience. The project is planned over eight months, ensuring rigorous data collection, analysis, and dissemination of findings.', 'critique': '```json\n{\n  "decision": "ACCEPT",\n  "feedback": "The draft is clear, well-structured, and presents a compelling study on the impact of community gardens on urban residents\' wellbeing. It effectively outlines the mixed-methods approach, including both quantitative and qualitative data sources, and demonstrates relevance through multi-city observations and a comprehensive literature review. The objectives are meaningful and aligned with public health and urban planning interests. The timeframe and scope appear reasonable. No major revisions are needed, though ...

# %%
print("Final summary:", final_entry["summary"][:400], "...")
print("Critique:", final_entry["critique"])
print("Iterations:", report.context.get("iteration"))
print("Ledger entries:", len(report.ledger))
# Out:
# Final summary: This research investigates the impact of community gardens on the physical, mental, and social wellbeing of urban residents. Combining quantitative surveys and health data with qualitative interviews, focus groups, and case studies, the study explores how community gardening influences mental health, fosters social cohesion, and improves physical health indicators. A comprehensive literature revie ...
# Critique: ```json
# {
#   "decision": "ACCEPT",
#   "feedback": "The draft is clear, well-structured, and presents a compelling study on the impact of community gardens on urban residents' wellbeing. It effectively outlines the mixed-methods approach, including both quantitative and qualitative data sources, and demonstrates relevance through multi-city observations and a comprehensive literature review. The objectives are meaningful and aligned with public health and urban planning interests. The timeframe and scope appear reasonable. No major revisions are needed, though adding more details about participant selection or data analysis methods could strengthen the proposal further in future drafts."
# }
# ```
# Iterations: None
# Ledger entries: 15

# %% [markdown]
# ### Inspect Instruments
#
# ```report.ledger[:5]```
#
# Use the ledger to review every node activation and token movement.

# %%
def print_ledger(report):
  for event in report.ledger:
    if event.event_type == "node_completed":
      print(f"{event.timestamp.isoformat()} | {event.event_type} | {event.source_node}")
    else:
      print(f"{event.timestamp.isoformat()} | {event.event_type} | {event.source_node} -> {event.target_node}")


print_ledger(report)
# Out:
# 2025-09-25T04:47:49.154416+00:00 | token_enqueued | __entry__ -> planner
# 2025-09-25T04:47:49.154437+00:00 | token_dequeued | __entry__ -> planner
# 2025-09-25T04:47:52.843611+00:00 | token_enqueued | planner -> researcher
# 2025-09-25T04:47:52.843759+00:00 | node_completed | planner
# 2025-09-25T04:47:52.843784+00:00 | token_dequeued | planner -> researcher
# 2025-09-25T04:47:54.472207+00:00 | token_enqueued | researcher -> writer
# 2025-09-25T04:47:54.472422+00:00 | node_completed | researcher
# 2025-09-25T04:47:54.472454+00:00 | token_dequeued | researcher -> writer
# 2025-09-25T04:47:59.076407+00:00 | token_enqueued | writer -> critic
# 2025-09-25T04:47:59.076573+00:00 | node_completed | writer
# 2025-09-25T04:47:59.076608+00:00 | token_dequeued | writer -> critic
# 2025-09-25T04:48:00.780417+00:00 | token_enqueued | critic -> finalize
# 2025-09-25T04:48:00.780681+00:00 | node_completed | critic
# 2025-09-25T04:48:00.780753+00:00 | token_dequeued | critic -> finalize
# 2025-09-25T04:48:00.781384+00:00 | node_completed | finalize

# %% [markdown]
# ## 5. Benefits Recap
#
# - **Telemetry**: `track_node` spans emitted automatically via the adapter.
# - **Audit trail**: `ExecutionReport.ledger` stores a full tape of the run.
# - **Logic IDs**: deterministic hashing of the LangGraph structure for idempotency.
# - **Developer ergonomics**: one call to `from_langgraph` replaces manual instrumentation.
#
# Next steps: explore the roadmap for persistence (`docs/vision/codon-workload-design-philosophy.md`) and the design guidelines for adapters (`docs/guides/workload-mixin-guidelines.md`).
